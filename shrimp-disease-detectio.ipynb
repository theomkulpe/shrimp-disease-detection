# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# # Load Data

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/kaggle/input/shrimp-disease-detection/Annotated Diseased Shrimp Images'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

# We want to be able to train our model on an `accelerator <https://pytorch.org/docs/stable/torch.html#accelerators>`__
# such as CUDA, MPS, MTIA, or XPU. If the current accelerator is available, we will use it. Otherwise, we use the CPU.

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class_names
# Out:
# ['BG', 'WSSV']

# %% [markdown]
# # Visualize a few images

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# # Training the model

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path, weights_only=True))
    return model

# %% [markdown]
# # Visualizing the model predictions

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# # Finetuning the ConvNet

# %%
model_ft = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 177MB/s]

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.5924 Acc: 0.7182
# val Loss: 2.8783 Acc: 0.3924
#
# Epoch 1/24
# ----------
# train Loss: 0.6677 Acc: 0.7371
# val Loss: 1.9339 Acc: 0.3671
#
# Epoch 2/24
# ----------
# train Loss: 0.5558 Acc: 0.7507
# val Loss: 1.6347 Acc: 0.3924
#
# Epoch 3/24
# ----------
# train Loss: 0.4741 Acc: 0.8211
# val Loss: 2.2832 Acc: 0.3544
#
# Epoch 4/24
# ----------
# train Loss: 0.4544 Acc: 0.8266
# val Loss: 1.2921 Acc: 0.4177
#
# Epoch 5/24
# ----------
# train Loss: 0.3599 Acc: 0.8618
# val Loss: 1.4725 Acc: 0.3671
#
# Epoch 6/24
# ----------
# train Loss: 0.4862 Acc: 0.8401
# val Loss: 1.5174 Acc: 0.3797
#
# Epoch 7/24
# ----------
# train Loss: 0.2973 Acc: 0.8862
# val Loss: 1.7155 Acc: 0.3924
#
# Epoch 8/24
# ----------
# train Loss: 0.3262 Acc: 0.8672
# val Loss: 1.8054 Acc: 0.3924
#
# Epoch 9/24
# ----------
# train Loss: 0.2699 Acc: 0.8943
# val Loss: 1.5297 Acc: 0.3797
#
# Epoch 10/24
# ----------
# train Loss: 0.2846 Acc: 0.8997
# val Loss: 2.0053 Acc: 0.3924
#
# Epoch 11/24
# ----------
# train Loss: 0.3370 Acc: 0.8645
# val Loss: 1.4917 Acc: 0.3671
#
# Epoch 12/24
# ----------
# train Loss: 0.2369 Acc: 0.9187
# val Loss: 1.8056 Acc: 0.3797
#
# Epoch 13/24
# ----------
# train Loss: 0.2024 Acc: 0.9187
# val Loss: 1.5200 Acc: 0.3671
#
# Epoch 14/24
# ----------
# train Loss: 0.2146 Acc: 0.9241
# val Loss: 1.8519 Acc: 0.3418
#
# Epoch 15/24
# ----------
# train Loss: 0.2165 Acc: 0.9214
# val Loss: 1.9553 Acc: 0.3797
#
# Epoch 16/24
# ----------
# train Loss: 0.1865 Acc: 0.9241
# val Loss: 1.7743 Acc: 0.3797
#
# Epoch 17/24
# ----------
# train Loss: 0.2113 Acc: 0.9079
# val Loss: 1.8575 Acc: 0.3671
#
# Epoch 18/24
# ----------
# train Loss: 0.1972 Acc: 0.9322
# val Loss: 1.8058 Acc: 0.3671
#
# Epoch 19/24
# ----------
# train Loss: 0.1984 Acc: 0.9295
# val Loss: 1.8338 Acc: 0.3797
#
# Epoch 20/24
# ----------
# train Loss: 0.2702 Acc: 0.8970
# val Loss: 1.7820 Acc: 0.3797
#
# Epoch 21/24
# ----------
# train Loss: 0.1882 Acc: 0.9350
# val Loss: 1.9896 Acc: 0.3797
#
# Epoch 22/24
# ----------
# train Loss: 0.2140 Acc: 0.9133
# val Loss: 1.7910 Acc: 0.3671
#
# Epoch 23/24
# ----------
# train Loss: 0.2915 Acc: 0.8889
# val Loss: 1.8838 Acc: 0.3924
#
# Epoch 24/24
# ----------
# train Loss: 0.1728 Acc: 0.9404
# val Loss: 1.7121 Acc: 0.3418
#
# Training complete in 3m 32s
# Best val Acc: 0.417722

# %%
visualize_model(model_ft)

# %% [markdown]
# # ConvNet as fixed feature extractor

# %%
model_conv = torchvision.models.resnet18(weights='IMAGENET1K_V1')
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 2)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.6277 Acc: 0.6640
# val Loss: 0.8962 Acc: 0.5316
#
# Epoch 1/24
# ----------
# train Loss: 0.4446 Acc: 0.8130
# val Loss: 1.3441 Acc: 0.4304
#
# Epoch 2/24
# ----------
# train Loss: 0.4966 Acc: 0.7913
# val Loss: 1.1660 Acc: 0.4430
#
# Epoch 3/24
# ----------
# train Loss: 0.4491 Acc: 0.8076
# val Loss: 0.8122 Acc: 0.6456
#
# Epoch 4/24
# ----------
# train Loss: 0.3672 Acc: 0.8238
# val Loss: 0.7118 Acc: 0.6709
#
# Epoch 5/24
# ----------
# train Loss: 0.4105 Acc: 0.8211
# val Loss: 1.4622 Acc: 0.4304
#
# Epoch 6/24
# ----------
# train Loss: 0.3455 Acc: 0.8509
# val Loss: 0.6928 Acc: 0.6709
#
# Epoch 7/24
# ----------
# train Loss: 0.4119 Acc: 0.8320
# val Loss: 1.1655 Acc: 0.4810
#
# Epoch 8/24
# ----------
# train Loss: 0.3573 Acc: 0.8455
# val Loss: 0.7733 Acc: 0.6456
#
# Epoch 9/24
# ----------
# train Loss: 0.3760 Acc: 0.8184
# val Loss: 0.9115 Acc: 0.5316
#
# Epoch 10/24
# ----------
# train Loss: 0.3696 Acc: 0.8455
# val Loss: 0.9694 Acc: 0.5190
#
# Epoch 11/24
# ----------
# train Loss: 0.3342 Acc: 0.8509
# val Loss: 1.0353 Acc: 0.4810
#
# Epoch 12/24
# ----------
# train Loss: 0.3978 Acc: 0.8374
# val Loss: 0.8431 Acc: 0.6329
#
# Epoch 13/24
# ----------
# train Loss: 0.3192 Acc: 0.8645
# val Loss: 1.0819 Acc: 0.5443
#
# Epoch 14/24
# ----------
# train Loss: 0.2999 Acc: 0.8780
# val Loss: 0.7830 Acc: 0.6709
#
# Epoch 15/24
# ----------
# train Loss: 0.3329 Acc: 0.8455
# val Loss: 0.8379 Acc: 0.5949
#
# Epoch 16/24
# ----------
# train Loss: 0.3862 Acc: 0.8157
# val Loss: 0.8690 Acc: 0.5696
#
# Epoch 17/24
# ----------
# train Loss: 0.3028 Acc: 0.8645
# val Loss: 0.8895 Acc: 0.5949
#
# Epoch 18/24
# ----------
# train Loss: 0.3186 Acc: 0.8509
# val Loss: 0.7661 Acc: 0.6329
#
# Epoch 19/24
# ----------
# train Loss: 0.3357 Acc: 0.8672
# val Loss: 0.9202 Acc: 0.5696
#
# Epoch 20/24
# ----------
# train Loss: 0.3111 Acc: 0.8564
# val Loss: 0.9111 Acc: 0.5696
#
# Epoch 21/24
# ----------
# train Loss: 0.3357 Acc: 0.8401
# val Loss: 0.8110 Acc: 0.6203
#
# Epoch 22/24
# ----------
# train Loss: 0.3196 Acc: 0.8455
# val Loss: 0.7298 Acc: 0.6329
#
# Epoch 23/24
# ----------
# train Loss: 0.3324 Acc: 0.8672
# val Loss: 1.0666 Acc: 0.4937
#
# Epoch 24/24
# ----------
# train Loss: 0.3393 Acc: 0.8482
# val Loss: 1.0103 Acc: 0.5063
#
# Training complete in 3m 46s
# Best val Acc: 0.670886

# %%
visualize_model(model_conv)

plt.ioff()
plt.show()

# %%
def visualize_model_predictions(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        ax = plt.subplot(2,2,1)
        ax.axis('off')
        ax.set_title(f'Predicted: {class_names[preds[0]]}')
        imshow(img.cpu().data[0])

        model.train(mode=was_training)

# %%
# /kaggle/input/shrimp-disease-detection/Annotated Diseased Shrimp Images/test/BG/BG-66-img-3.jpg

def predict(img_path):
    img = Image.open(img_path)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)
        return class_names[preds[0]]

# %%
print(predict('/kaggle/input/shrimp-disease-detection/Annotated Diseased Shrimp Images/test/BG/BG-66-img-3.jpg'))
# Out:
# BG

# %%
torch.save(model_conv, 'model.pth')

# %%
model = torch.load('model.pth', weights_only = False)
model.eval()

# %%
visualize_model_predictions(
    model_conv,
    img_path='data/hymenoptera_data/val/bees/72100438_73de9f17af.jpg'
)

plt.ioff()
plt.show()
